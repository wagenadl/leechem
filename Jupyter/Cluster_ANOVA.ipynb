# %% [markdown]
# ## Import of relevant python modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import networkx as nx
import plotly.offline
import plotly.graph_objects as go
from scipy.stats import ks_2samp
from sbemdb import SBEMDB
from cleandb import clean_db, clean_db_uct
import os
import scipy.io
import math
import cmath
import pickle
import random
import csv
import mapping

np.warnings.filterwarnings('ignore')

# %%
def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# ## Import database

# %%
db = SBEMDB() # connect to DB
db = clean_db(db)
x,y,z = db.segments(444)
# Out:
# trees Before 398
# trees After 46
# nodes Before 37481
# nodes After 16320
# nodecons Before 73994
# nodecons After 32548
# syncons Before 1199
# syncons After 826
# synapses Before 552
# synapses After 535

# %% [markdown]
# ## Load phase and magnitude values

# %%
#Get mag and phase values for each roi
col_names =  ['roi','mag','phase','coherence']
data_coh = pd.DataFrame(columns = col_names)

file_name = '123'

path_mag = os.path.join('..', 'data', 'roi_mag_' + file_name + '.mat')
mat = scipy.io.loadmat(path_mag)

path_phase = os.path.join('..', 'data', 'roi_phase_' + file_name + '.mat')
phase_mat = scipy.io.loadmat(path_phase)

#save magnitude values in mag column
for roin, mag in enumerate(mat['roi_mag'][0]):
    data_coh.loc[roin,'roi'] = roin + 1
    data_coh.loc[data_coh['roi'] == roin + 1, 'mag'] = mag 
    
#save phase values in phase column
# phase is between -pi and pi 
for roin, phase in enumerate(phase_mat['roi_phase'][0]):
    data_coh.loc[roin,'roi'] = roin + 1
    data_coh.loc[data_coh['roi'] == roin + 1, 'phase'] = phase

#Calculate Coherence:
for i,val in data_coh.iterrows():
    data_coh.loc[i,'coherence'] = val['mag'] * math.cos(val['phase']) +  1j*val['mag']*math.sin(val['phase']);

# %% [markdown]
# ## Cluster-based ANOVA analysis

# %%
#load data
#then construct a dataframe with columns'sid','tid','cluster_id','coherence'
#note that synapses which are "unclustered" are excluded from the following analysis

#load data from .pkl file
data_pkl = load_obj("saved_param_clusters_path_2-5");

# %%
#Dataframe with columns'sid','tid','cluster_id','coherence'
#Note that synapses which are "unclustered" are excluded from the following analysis

#prepare all needed variables
cluster_id = 0;
data_by_params = dict();
corresponding_tid = dict();

col_names =  ['sid','tid','cluster_id','coherence'];

'''Method for getting the corresponding tid
We are storing already recovered tids since it's faster to get them from dictionary than 
to execute query each time we need the tid.
'''
def find_corresponding_tid(sid):
    global corresponding_tid;
    if sid in corresponding_tid.keys():
        return corresponding_tid[sid];
    try:
        tid = db.synapses(f's.sid={sid}')[3][0];
        corresponding_tid[sid] = tid;
        return tid;
    except:
        return np.NaN;
    
    
for key in data_pkl:
    counter = 0;
    dframe = pd.DataFrame(columns = col_names);
    for synapse_group in data_pkl[key]['clusters']:
        for synapse in synapse_group:
            dframe.loc[counter,'cluster_id'] = cluster_id;
            dframe.loc[counter,'sid'] = synapse.sid;
            
            tid = find_corresponding_tid(synapse.sid);
            roi = db.mapping.sbem2roi[tid];
            
            dframe.loc[counter,'tid'] = tid;
            dframe.loc[counter,'coherence'] = data_coh[data_coh['roi']==roi]['coherence'].iloc[0];
            counter += 1;
        cluster_id += 1;
    data_by_params[key] = dframe

# %%
def anova(data, randomize_cluster=False):
    data = data.copy()
    if randomize_cluster:
        
        tid_coh_df = data.groupby('tid').first()[['coherence']]
        coherences = tid_coh_df['coherence'].values
        np.random.shuffle(coherences)
        for i, tid in enumerate(tid_coh_df.index):
            data.loc[data['tid'] == tid, 'coherence'] = coherences[i]
        
               
    clusters = np.unique(data['cluster_id'])
    clusters_used = {cluster_id: True for cluster_id in clusters}
    
    n_clust = 0 # number of clusters
    n_tot = 0   # total number of synapses used in the analysis
    # Calculate the mean of coherence values X_j for each cluster j
    means_per_cluster = []
    for cluster_id in clusters:
        clust_data_grouped = data[data['cluster_id'] == cluster_id].groupby('tid').first()
        if len(clust_data_grouped) > 1:
            means_per_cluster.append(clust_data_grouped['coherence'].mean())
            n_clust += 1
            n_tot += len(clust_data_grouped)
        else:
            clusters_used[cluster_id] = False
    
    # Calculating degrees of freedom
    # Variable df_clust: k-1, with k the number of clusters 
    # Variable df_tot: N-1, with N the number of total synapses
    # Variable df_res: N  - k 
    df_clust = n_clust - 1
    df_tot = n_tot - 1
    df_res = n_tot - n_clust
    

    # 2. Calculate the mean of coherence values X_t of all synapses
    mean_all_synapses = data[data['cluster_id'].isin([cl_id for cl_id in clusters_used.keys() if clusters_used[cl_id]])]\
                        .groupby(['cluster_id', 'tid']).first()['coherence'].mean()
    
    # Calculation of sums of absolute squared differences

    # SSB: Sum_j(abs((X_j-X_t))^2)
    # X_j-X_t: Subtract the mean of each cluster from the total mean. Square and take the absolute value, and sum all terms
    # up
    SSB = 0
    i = 0
    for cluster_id in clusters:
        if clusters_used[cluster_id]:
            n = np.unique(data.loc[data['cluster_id'] == cluster_id, 'tid']).shape[0]
            SSB += n*(np.square(abs(means_per_cluster[i] - mean_all_synapses)))
            i += 1
        

    # SSE: Sum_j Sum_i (abs(X_i-X_j)^2); X_i are coherence values for single synapses in the cluster j
    # X_i-X_j: Subtract each synapse's coherence from its cluster's mean value. Summation for all synapses in a cluster
    # and then over all clusters
    SSE = 0
    i = 0
    for cluster_id in clusters:
        if clusters_used[cluster_id]:
            cluster_mean = means_per_cluster[i]
            clust_data_grouped = data[data['cluster_id'] == cluster_id].groupby('tid').first()
            for j, row in clust_data_grouped.iterrows():
                SSE += np.square(abs(row['coherence'] - cluster_mean))
            i += 1
        
    # Calculate MSE and MSB   
    MSB = SSB/df_clust
    MSE = SSE/df_res
    
    #F-ratio
    F = MSB/MSE
    
    # Check p-value: 1-cdf of F-distribution
    p_value = 1-scipy.stats.f.cdf(F, df_clust, df_res)
    return F, p_value

# %% [markdown]
# ## Define empirical p-values

# %%
#Empirical p-value calculation
#Davison & Hickley, 1997

def test_rand(F_true, x_times, data):
    n_times_larger = 0
    for i in range(x_times):
        F_rand, _ = anova(data, randomize_cluster=True)
        if F_true < F_rand: 
            n_times_larger += 1
    p_value = (n_times_larger+1)/(x_times+1)
    return p_value

# %%
for val in data_by_params:
    if val[1]>105: continue
    if val[0]>val[1]: continue
    F_true, p_value = anova(data_by_params[val])
    print(f'Results parametrical: {val} | F true={F_true} | p_value={p_value}')
# Out:
# Results parametrical: (2.5, 10) | F true=3.183467216018253 | p_value=0.05752132324429837
# Results parametrical: (2.5, 15) | F true=1.9664560814828975 | p_value=0.16398717302692045
# Results parametrical: (2.5, 20) | F true=1.380343388801116 | p_value=0.29409691321349196
# Results parametrical: (2.5, 25) | F true=0.580861171162589 | p_value=0.6818694932482852
# Results parametrical: (2.5, 30) | F true=0.55245433883393 | p_value=0.7343350686470035
# Results parametrical: (2.5, 35) | F true=0.55245433883393 | p_value=0.7343350686470035
# Results parametrical: (2.5, 40) | F true=0.55245433883393 | p_value=0.7343350686470035
# Results parametrical: (2.5, 45) | F true=0.6709648638065417 | p_value=0.6938874972268758
# Results parametrical: (2.5, 50) | F true=1.0599398955788666 | p_value=0.42143837589955147
# Results parametrical: (2.5, 55) | F true=1.0599398955788666 | p_value=0.42143837589955147
# Results parametrical: (2.5, 60) | F true=1.1545338634118643 | p_value=0.3703798412908955
# Results parametrical: (2.5, 65) | F true=1.1545338634118643 | p_value=0.3703798412908955
# Results parametrical: (2.5, 70) | F true=1.203358403372413 | p_value=0.3449356776467709
# Results parametrical: (2.5, 75) | F true=1.3707978075434593 | p_value=0.27181553260448355
# Results parametrical: (2.5, 80) | F true=1.3707978075434593 | p_value=0.27181553260448355
# Results parametrical: (2.5, 85) | F true=1.3707978075434593 | p_value=0.27181553260448355
# Results parametrical: (2.5, 90) | F true=1.2432572358267187 | p_value=0.32298210888005974
# Results parametrical: (2.5, 95) | F true=1.301245423076484 | p_value=0.29379042498736996
# Results parametrical: (2.5, 100) | F true=1.11170116142531 | p_value=0.38786344458630495
# Results parametrical: (2.5, 105) | F true=0.982452105486973 | p_value=0.4657730933885653
# Results parametrical: (5.0, 10) | F true=1.155248863333011 | p_value=0.3770659819742608
# Results parametrical: (5.0, 15) | F true=1.3518040561073619 | p_value=0.2609530792306527
# Results parametrical: (5.0, 20) | F true=1.3809026408384748 | p_value=0.23071465604111496
# Results parametrical: (5.0, 25) | F true=0.8851291363000463 | p_value=0.5868192283134229
# Results parametrical: (5.0, 30) | F true=0.8434695054983988 | p_value=0.6363839956227724
# Results parametrical: (5.0, 35) | F true=0.8999686249327774 | p_value=0.5834871597692962
# Results parametrical: (5.0, 40) | F true=0.8999686249327774 | p_value=0.5834871597692962
# Results parametrical: (5.0, 45) | F true=0.9782438465922857 | p_value=0.5078323459705298
# Results parametrical: (5.0, 50) | F true=1.1486448946113934 | p_value=0.3595101436559942
# Results parametrical: (5.0, 55) | F true=1.1675566238849793 | p_value=0.3418609301214408
# Results parametrical: (5.0, 60) | F true=1.1845668975529493 | p_value=0.3289985123474277
# Results parametrical: (5.0, 65) | F true=1.2823625472074016 | p_value=0.2631433807601855
# Results parametrical: (5.0, 70) | F true=1.392492683872066 | p_value=0.20677725518407175
# Results parametrical: (5.0, 75) | F true=1.4518723722265732 | p_value=0.1787757663597105
# Results parametrical: (5.0, 80) | F true=1.519618670091204 | p_value=0.15640689295406562
# Results parametrical: (5.0, 85) | F true=1.5250822911483204 | p_value=0.15903000907704445
# Results parametrical: (5.0, 90) | F true=1.5250822911483204 | p_value=0.15903000907704445
# Results parametrical: (5.0, 95) | F true=1.5250822911483204 | p_value=0.15903000907704445
# Results parametrical: (5.0, 100) | F true=1.5258715956421431 | p_value=0.15635024465447145
# Results parametrical: (5.0, 105) | F true=1.5258715956421431 | p_value=0.15635024465447145
# Results parametrical: (7.5, 10) | F true=1.2450547404055932 | p_value=0.30088751189388696
# Results parametrical: (7.5, 15) | F true=1.2826508386074729 | p_value=0.27508452492437585
# Results parametrical: (7.5, 20) | F true=1.2631037152633127 | p_value=0.27660665539640883
# Results parametrical: (7.5, 25) | F true=1.0350927063309112 | p_value=0.45177596029991585
# Results parametrical: (7.5, 30) | F true=1.0062293532295545 | p_value=0.48005432179069785
# Results parametrical: (7.5, 35) | F true=0.8973744781574075 | p_value=0.5921133300922673
# Results parametrical: (7.5, 40) | F true=0.9883365892186964 | p_value=0.4955284340318584
# Results parametrical: (7.5, 45) | F true=1.0560339811146144 | p_value=0.42966199474369726
# Results parametrical: (7.5, 50) | F true=1.233281741061493 | p_value=0.29006951972928974
# Results parametrical: (7.5, 55) | F true=1.221272494824965 | p_value=0.2951740053198366
# Results parametrical: (7.5, 60) | F true=1.316116210407261 | p_value=0.2338243914814121
# Results parametrical: (7.5, 65) | F true=1.2853771811460504 | p_value=0.24828790770156595
# Results parametrical: (7.5, 70) | F true=1.477017631044102 | p_value=0.15218867566416794
# Results parametrical: (7.5, 75) | F true=1.5814152940537307 | p_value=0.11391500371891872
# Results parametrical: (7.5, 80) | F true=1.7319768827581237 | p_value=0.0758252855002236
# Results parametrical: (7.5, 85) | F true=1.7465438413628689 | p_value=0.07626718094152429
# Results parametrical: (7.5, 90) | F true=1.4307123872425616 | p_value=0.18495393402650162
# Results parametrical: (7.5, 95) | F true=1.465677772474348 | p_value=0.16921968285230393
# Results parametrical: (7.5, 100) | F true=1.5199149547601327 | p_value=0.14567576154547912
# Results parametrical: (7.5, 105) | F true=1.5199149547601327 | p_value=0.14567576154547912
# Results parametrical: (10.0, 10) | F true=1.0108250995148405 | p_value=0.48222647133409313
# Results parametrical: (10.0, 15) | F true=0.9543572187658136 | p_value=0.541861697862247
# Results parametrical: (10.0, 20) | F true=1.0400199132647874 | p_value=0.4490530194677981
# Results parametrical: (10.0, 25) | F true=0.8534579983730298 | p_value=0.6505804801538672
# Results parametrical: (10.0, 30) | F true=0.9335056611353978 | p_value=0.565729608183456
# Results parametrical: (10.0, 35) | F true=0.7439316287843964 | p_value=0.7917711947971592
# Results parametrical: (10.0, 40) | F true=0.7949966642536218 | p_value=0.7308250986601197
# Results parametrical: (10.0, 45) | F true=0.851153042070212 | p_value=0.6649118910724199
# Results parametrical: (10.0, 50) | F true=0.9424199193342767 | p_value=0.5482611731181215
# Results parametrical: (10.0, 55) | F true=1.0031803344201198 | p_value=0.4792506335184259
# Results parametrical: (10.0, 60) | F true=1.0284423847006419 | p_value=0.4501457575106702
# Results parametrical: (10.0, 65) | F true=1.0284423847006419 | p_value=0.4501457575106702
# Results parametrical: (10.0, 70) | F true=1.08448961377051 | p_value=0.3917171093077807
# Results parametrical: (10.0, 75) | F true=1.1688223057812561 | p_value=0.3164145599811582
# Results parametrical: (10.0, 80) | F true=1.2507632860613178 | p_value=0.2565882107044608
# Results parametrical: (10.0, 85) | F true=1.2655870159082567 | p_value=0.25357110368036984
# Results parametrical: (10.0, 90) | F true=1.2655870159082567 | p_value=0.25357110368036984
# Results parametrical: (10.0, 95) | F true=1.2939492843254152 | p_value=0.2376166737254004
# Results parametrical: (10.0, 100) | F true=1.3179348744696353 | p_value=0.2228480643031231
# Results parametrical: (10.0, 105) | F true=1.1299933549126824 | p_value=0.35334273967411356
# Results parametrical: (12.5, 15) | F true=0.9348033608803662 | p_value=0.5667959139456633
# Results parametrical: (12.5, 20) | F true=1.2343514341898563 | p_value=0.2664820283373672
# Results parametrical: (12.5, 25) | F true=0.9148029613722576 | p_value=0.587703641654902
# Results parametrical: (12.5, 30) | F true=0.9803146011631163 | p_value=0.5130114824618657
# Results parametrical: (12.5, 35) | F true=0.9248817118650069 | p_value=0.5793821759034472
# Results parametrical: (12.5, 40) | F true=0.9770636703992007 | p_value=0.5142705889071686
# Results parametrical: (12.5, 45) | F true=1.0493897808544406 | p_value=0.43076841116786
# Results parametrical: (12.5, 50) | F true=1.1725494317999459 | p_value=0.3110810544263265
# Results parametrical: (12.5, 55) | F true=1.08883332167453 | p_value=0.38699526799411654
# Results parametrical: (12.5, 60) | F true=1.1643171927132683 | p_value=0.31463069409483757
# Results parametrical: (12.5, 65) | F true=1.0277481329477733 | p_value=0.45075346610894096
# Results parametrical: (12.5, 70) | F true=1.1376220277979525 | p_value=0.3400988793299544
# Results parametrical: (12.5, 75) | F true=1.1649526166886943 | p_value=0.3183724493491594
# Results parametrical: (12.5, 80) | F true=1.1550877639115908 | p_value=0.32747914527380095
# Results parametrical: (12.5, 85) | F true=1.2322127217274441 | p_value=0.2745594425485254
# Results parametrical: (12.5, 90) | F true=1.2322127217274441 | p_value=0.2745594425485254
# Results parametrical: (12.5, 95) | F true=1.23687475987524 | p_value=0.27341203355972477
# Results parametrical: (12.5, 100) | F true=1.23687475987524 | p_value=0.27341203355972477
# Results parametrical: (12.5, 105) | F true=1.158712909091934 | p_value=0.331790898864168
# Results parametrical: (15.0, 15) | F true=0.746715566926548 | p_value=0.8020937130854615
# Results parametrical: (15.0, 20) | F true=1.0184568777318637 | p_value=0.47103067869929294
# Results parametrical: (15.0, 25) | F true=0.7735471167818343 | p_value=0.7695341490789784
# Results parametrical: (15.0, 30) | F true=0.7953628373965921 | p_value=0.7519342613116398
# Results parametrical: (15.0, 35) | F true=0.7461390631950593 | p_value=0.8065475513404914
# Results parametrical: (15.0, 40) | F true=0.7565678891667575 | p_value=0.7959914877684214
# Results parametrical: (15.0, 45) | F true=0.8126990990759387 | p_value=0.7295711782603764
# Results parametrical: (15.0, 50) | F true=0.8869494881363481 | p_value=0.6272707696844368
# Results parametrical: (15.0, 55) | F true=0.9301551461064068 | p_value=0.5704798896960411
# Results parametrical: (15.0, 60) | F true=0.9538349980976765 | p_value=0.5392015704630655
# Results parametrical: (15.0, 65) | F true=0.8774151906696526 | p_value=0.6311152947190628
# Results parametrical: (15.0, 70) | F true=0.9318479688635505 | p_value=0.561698208626291
# Results parametrical: (15.0, 75) | F true=0.9600039684845086 | p_value=0.5236114319597612
# Results parametrical: (15.0, 80) | F true=0.9460658407801552 | p_value=0.5375153440247343
# Results parametrical: (15.0, 85) | F true=1.0207399363073457 | p_value=0.45047027540948703
# Results parametrical: (15.0, 90) | F true=1.0207399363073457 | p_value=0.45047027540948703
# Results parametrical: (15.0, 95) | F true=1.0207399363073457 | p_value=0.45047027540948703
# Results parametrical: (15.0, 100) | F true=1.055767998248416 | p_value=0.41536193068702565
# Results parametrical: (15.0, 105) | F true=0.9457746297910251 | p_value=0.5132488529536647
# Results parametrical: (17.5, 20) | F true=1.0588428420289353 | p_value=0.4231149633905775
# Results parametrical: (17.5, 25) | F true=0.7702811453342929 | p_value=0.7769605203692267
# Results parametrical: (17.5, 30) | F true=0.7905204545800649 | p_value=0.761124428323724
# Results parametrical: (17.5, 35) | F true=0.7894699604156404 | p_value=0.7629174948872455
# Results parametrical: (17.5, 40) | F true=0.7996460377430977 | p_value=0.7514594935673516
# Results parametrical: (17.5, 45) | F true=0.8118980572706189 | p_value=0.7338491313841394
# Results parametrical: (17.5, 50) | F true=0.8845374815054959 | p_value=0.6329299679747642
# Results parametrical: (17.5, 55) | F true=0.9270168483294454 | p_value=0.5763570914550913
# Results parametrical: (17.5, 60) | F true=0.9930509370683961 | p_value=0.49234840976693284
# Results parametrical: (17.5, 65) | F true=0.9229304104506053 | p_value=0.5773277060631894
# Results parametrical: (17.5, 70) | F true=0.9733313842314621 | p_value=0.51139549400025
# Results parametrical: (17.5, 75) | F true=1.0309202430923285 | p_value=0.44368039898152545
# Results parametrical: (17.5, 80) | F true=0.9907531918727366 | p_value=0.4863206861526861
# Results parametrical: (17.5, 85) | F true=1.0329642405774047 | p_value=0.43890679468909966
# Results parametrical: (17.5, 90) | F true=1.0373159273252746 | p_value=0.43374235129216876
# Results parametrical: (17.5, 95) | F true=1.0368232410590827 | p_value=0.434036573635158
# Results parametrical: (17.5, 100) | F true=1.0782586920894153 | p_value=0.39458585936633317
# Results parametrical: (17.5, 105) | F true=0.9714757547555471 | p_value=0.4885863529906873
# Results parametrical: (20.0, 20) | F true=1.0588428420289353 | p_value=0.4231149633905775
# Results parametrical: (20.0, 25) | F true=0.769973738904505 | p_value=0.7808876095369863
# Results parametrical: (20.0, 30) | F true=0.7884468812604917 | p_value=0.7669022962636458
# Results parametrical: (20.0, 35) | F true=0.7647509217792727 | p_value=0.7955754256373979
# Results parametrical: (20.0, 40) | F true=0.7745019170804525 | p_value=0.7852245711143637
# Results parametrical: (20.0, 45) | F true=0.786151784667356 | p_value=0.7689034144200558
# Results parametrical: (20.0, 50) | F true=0.8533793403077793 | p_value=0.6758192952359003
# Results parametrical: (20.0, 55) | F true=0.8930846223979361 | p_value=0.6221247733298151
# Results parametrical: (20.0, 60) | F true=0.9561100466436734 | p_value=0.5391907016473121
# Results parametrical: (20.0, 65) | F true=0.890774725111383 | p_value=0.620250352824573
# Results parametrical: (20.0, 70) | F true=0.9492050601965517 | p_value=0.5403086355620645
# Results parametrical: (20.0, 75) | F true=1.0050978888527542 | p_value=0.4725263288142738
# Results parametrical: (20.0, 80) | F true=0.9635037899828597 | p_value=0.5171170526988124
# Results parametrical: (20.0, 85) | F true=1.0196770023647024 | p_value=0.45269549157769184
# Results parametrical: (20.0, 90) | F true=1.021884842829772 | p_value=0.4493592004607103
# Results parametrical: (20.0, 95) | F true=0.9959416963019245 | p_value=0.47282681838977814
# Results parametrical: (20.0, 100) | F true=1.0223673096898085 | p_value=0.44541527664049496
# Results parametrical: (20.0, 105) | F true=0.9733023761233242 | p_value=0.48670376449024166
# Results parametrical: (22.5, 25) | F true=0.769973738904505 | p_value=0.7808876095369863
# Results parametrical: (22.5, 30) | F true=0.7884468812604918 | p_value=0.7669022962636458
# Results parametrical: (22.5, 35) | F true=0.7647509217792727 | p_value=0.7955754256373979
# Results parametrical: (22.5, 40) | F true=0.7386324253871475 | p_value=0.8266446838427433
# Results parametrical: (22.5, 45) | F true=0.747291434522928 | p_value=0.8146870523923856
# Results parametrical: (22.5, 50) | F true=0.8281388836006961 | p_value=0.7086192857866943
# Results parametrical: (22.5, 55) | F true=0.8653481240215648 | p_value=0.6583046138507995
# Results parametrical: (22.5, 60) | F true=0.936016409849014 | p_value=0.5646274965140985
# Results parametrical: (22.5, 65) | F true=0.8714952565077098 | p_value=0.6449776037027108
# Results parametrical: (22.5, 70) | F true=0.9234975428338053 | p_value=0.5716695444878483
# Results parametrical: (22.5, 75) | F true=0.9773991736350832 | p_value=0.5043288115957598
# Results parametrical: (22.5, 80) | F true=0.8723973905772453 | p_value=0.6203021343089998
# Results parametrical: (22.5, 85) | F true=0.9459966876843335 | p_value=0.5325479184293536
# Results parametrical: (22.5, 90) | F true=1.0134675451881618 | p_value=0.4582490899421183
# Results parametrical: (22.5, 95) | F true=1.0082567482735354 | p_value=0.46170173625871747
# Results parametrical: (22.5, 100) | F true=1.032831385982077 | p_value=0.4361297954360802
# Results parametrical: (22.5, 105) | F true=0.9466005255043205 | p_value=0.5117807329168398
# Results parametrical: (25.0, 25) | F true=0.7297815583518983 | p_value=0.8290540389002841
# Results parametrical: (25.0, 30) | F true=0.7903656809851549 | p_value=0.7708475192996088
# Results parametrical: (25.0, 35) | F true=0.7642855979482571 | p_value=0.8026574990935734
# Results parametrical: (25.0, 40) | F true=0.7384627146017382 | p_value=0.8334729530607126
# Results parametrical: (25.0, 45) | F true=0.6979450259559044 | p_value=0.8721140799681708
# Results parametrical: (25.0, 50) | F true=0.7934650490828481 | p_value=0.7556504058926984
# Results parametrical: (25.0, 55) | F true=0.8304654604151045 | p_value=0.7065263758793556
# Results parametrical: (25.0, 60) | F true=0.8977505670764724 | p_value=0.6165351313911
# Results parametrical: (25.0, 65) | F true=0.836103871193657 | p_value=0.6933822895229361
# Results parametrical: (25.0, 70) | F true=0.8809066510273486 | p_value=0.6277623373250141
# Results parametrical: (25.0, 75) | F true=0.9240768637194235 | p_value=0.5708379383324446
# Results parametrical: (25.0, 80) | F true=0.806253293251417 | p_value=0.6973536585417794
# Results parametrical: (25.0, 85) | F true=0.8746394226601079 | p_value=0.6135396913092301
# Results parametrical: (25.0, 90) | F true=0.9355413344112468 | p_value=0.5411541908774916
# Results parametrical: (25.0, 95) | F true=0.9879741124985192 | p_value=0.4802268911872628
# Results parametrical: (25.0, 100) | F true=1.03422286525768 | p_value=0.43427307147006444
# Results parametrical: (25.0, 105) | F true=0.9445138712854343 | p_value=0.5135475449112452
# Results parametrical: (27.5, 30) | F true=0.7903656809851549 | p_value=0.7708475192996088
# Results parametrical: (27.5, 35) | F true=0.7642855979482571 | p_value=0.8026574990935734
# Results parametrical: (27.5, 40) | F true=0.7384627146017382 | p_value=0.8334729530607126
# Results parametrical: (27.5, 45) | F true=0.6979450259559044 | p_value=0.8721140799681708
# Results parametrical: (27.5, 50) | F true=0.7934650490828481 | p_value=0.7556504058926984
# Results parametrical: (27.5, 55) | F true=0.8304654604151045 | p_value=0.7065263758793556
# Results parametrical: (27.5, 60) | F true=0.8977505670764724 | p_value=0.6165351313911
# Results parametrical: (27.5, 65) | F true=0.836103871193657 | p_value=0.6933822895229361
# Results parametrical: (27.5, 70) | F true=0.8845254639944965 | p_value=0.6232533510374542
# Results parametrical: (27.5, 75) | F true=0.927704113204049 | p_value=0.5662924660370248
# Results parametrical: (27.5, 80) | F true=0.8100419287124092 | p_value=0.693137035566161
# Results parametrical: (27.5, 85) | F true=0.8794739315726577 | p_value=0.6079975479229449
# Results parametrical: (27.5, 90) | F true=0.9355413344112468 | p_value=0.5411541908774916
# Results parametrical: (27.5, 95) | F true=0.9879741124985192 | p_value=0.4802268911872628
# Results parametrical: (27.5, 100) | F true=1.03422286525768 | p_value=0.43427307147006444
# Results parametrical: (27.5, 105) | F true=0.9445138712854343 | p_value=0.5135475449112452

# %%
f_dict = {}
for params in data_by_params:
    f_dict[params],_ = anova(data_by_params[params]) 
save_obj(f_dict, 'F_values_by_params_2-5_newdb' + file_name)

# %%
def get_num_different_roi(clusters):
    counter = 0
    synapses_counter = 0
    for clust in clusters:
        rois = set()
        for syn in clust:
            tid = find_corresponding_tid(syn.sid)
            roi = db.mapping.sbem2roi[tid]
            rois.add(roi)
        if(len(rois) == 1): continue;
        counter += 1
        synapses_counter += len(clust)
    return counter,synapses_counter

# %%
#Calculte the empirical p-value and further cluster statistics
col_names =  ['Params','F_value','p_value','Numb_clusters','Numb_clusters_heterogen','Total_syn_clusters','Total_syn_heterogen_clusters']
results_anova = pd.DataFrame(columns = col_names)

for i, val in enumerate(data_by_params):
    if val[1]>105: continue
    if val[0]>val[1]: continue
    F_true, foo = anova(data_by_params[val])
    p_value_rand = test_rand(F_true, 1000, data_by_params[val])
    
    total_syn_clust = sum([len(el) for el in data_pkl[val]['clusters']])
    clust_het,syn_het = get_num_different_roi(data_pkl[val]['clusters'])
    
    results_anova.loc[i,'Params'] = val
    results_anova.loc[i,'F_value'] = F_true
    results_anova.loc[i,'p_value'] = p_value_rand
    results_anova.loc[i,'Numb_clusters'] = len(data_pkl[val]['clusters'])
    results_anova.loc[i,'Numb_clusters_heterogen'] = clust_het
    results_anova.loc[i,'Total_syn_clusters'] = total_syn_clust
    results_anova.loc[i,'Total_syn_heterogen_clusters'] = syn_het
    
print(type(results_anova))
results_anova.to_csv('Results_' + file_name + '.csv')

# %%
#Example calculation
data_params = data_by_params[(5, 55)]

# result 1
F_true, p_value = anova(data_params)
print(f'Results parametrical: F true={F_true} | p_value={p_value}')

# result 2 - randomized
p_value_rand = test_rand(F_true, 300, data_params)

print(f'Results randomized: F true={F_true} | p_value={p_value_rand}')
# Out:
# Results parametrical: F true=1.5811543052589698 | p_value=0.13374925112665892
# Results randomized: F true=1.5811543052589698 | p_value=0.13861386138613863
